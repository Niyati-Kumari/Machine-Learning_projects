# %%
import pandas as pd

# %%
df = pd.read_csv("Downloads/archive (1)/Housing.csv")

# %%
X = df[["area", "bedrooms", "bathrooms"]]

# %%
Y = df["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr = lr.fit(X_train, Y_train)

# %%
result = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(Y_test, result)

# %%
import numpy as np

# %%
rmse = np.sqrt(mse)

# %%
mae = mean_absolute_error(Y_test, result)

# %%
r2 = r2_score(Y_test, result)

# %%
# Print metrics
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
print(f"R^2 Score: {r2}")
# Out:
# Root Mean Squared Error: 1393437.3343709807
# Mean Absolute Error: 1013073.5823018769
# R^2 Score: 0.434428999201278

# %%
import matplotlib.pyplot as plt

# %%
# Plot predictions vs. true values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, result)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("True Values vs Predictions")
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], 'r--', lw=2)  # Perfect prediction line
plt.show()

# %%
print("Coefficients:", lr.coef_)
# Out:
# Coefficients: [4.21967715e+02 3.94006729e+05 1.45397279e+06]
